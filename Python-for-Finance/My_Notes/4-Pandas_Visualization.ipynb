# %% [markdown]
# # Pandas Built-in Data Visualization

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# interaktif görsel yaratma (sadece jupyter notebook için)
# %matplotlib notebook

# seaborn ile grafik değişiyor
# import seaborn as sns

# %%
df1 = pd.read_csv(r'C:\Users\Ugur\Desktop\Python\Udemy\Python-for-Finance\04-Visualization-Matplotlib-Pandas\04-02-Pandas Visualization\df1',index_col=0)
df2 = pd.read_csv(r'C:\Users\Ugur\Desktop\Python\Udemy\Python-for-Finance\04-Visualization-Matplotlib-Pandas\04-02-Pandas Visualization\df2')

# %% [markdown]
# **Style Sheets**

# %%
df1['A'].hist()

# %%
plt.style.use('ggplot')

# %%
df1['A'].hist()

# %%
plt.style.use('bmh')
df1['A'].hist()

# %%
plt.style.use('dark_background')
df1['A'].hist()

# %%
plt.style.use('fivethirtyeight')
df1['A'].hist()

# %%
plt.style.use('ggplot')

# %% [markdown]
# ## Plot Types

# %% [markdown]
# * df.plot.area
# * df.plot.barh
# * df.plot.density
# * df.plot.hist
# * df.plot.line
# * df.plot.scatter
# * df.plot.bar
# * df.plot.box
# * df.plot.hexbin
# * df.plot.kde
# * df.plot.pie

# %% [markdown]
# **Area**

# %%
df2.plot.area(alpha=0.4)

# %% [markdown]
# **Barplots**

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %% [markdown]
# **Histograms**

# %%
df1['A'].plot.hist(bins=50)

# %% [markdown]
# **Line Plots**

# %%
df1.plot.line(x=df1.index,y='B',figsize=(12,3),lw=1)

# %% [markdown]
# **Scatter Plots**

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*200)
# Out:
# C:\Users\Ugur\Anaconda3\lib\site-packages\matplotlib\collections.py:853: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# **BoxPlots**

# %%
df2.plot.box() # Can also pass a by= argument for groupby

# %% [markdown]
# **Hexagonal Bin Plot**

# %%
df = pd.DataFrame(np.random.randn(1000, 2), columns=['a', 'b'])
df.plot.hexbin(x='a',y='b',gridsize=25,cmap='Oranges')

# %% [markdown]
# **Kernel Density Estimation plot (KDE)**

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()

# %% [markdown]
# # Visualizing Time Series Data

# %%
mcdon = pd.read_csv(r'C:\Users\Ugur\Desktop\Python\Udemy\Python-for-Finance\04-Visualization-Matplotlib-Pandas\04-02-Pandas Visualization\mcdonalds.csv',index_col='Date',parse_dates=True)

# %%
mcdon.head()
# Out:
#             Adj. Close  Adj. Volume
# Date
# 1970-01-02    0.209761    2825604.0
# 1970-01-05    0.213316    2210449.5
# 1970-01-06    0.214501    1951168.5
# 1970-01-07    0.213316    2728768.5
# 1970-01-08    0.213316    2242404.0

# %%
# Veriler birbirleri ile alakalı olmadığından, bu şekilde plot kullanmak mantıklı değil
mcdon.plot()

# %%
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsOrig)
mpl.rcParams.update(mpl.rcParamsDefault)

# %%
mcdon['Adj. Close'].plot()

# %%
mcdon['Adj. Volume'].plot()

# %%
mcdon['Adj. Close'].plot(figsize=(12,8))

# %%
mcdon['Adj. Close'].plot(figsize=(12,8))
plt.ylabel('Close Price')
plt.xlabel('Overwrite Date Index')
plt.title('Mcdonalds')
# Out:
# Text(0.5,1,'Mcdonalds')

# %%
mcdon['Adj. Close'].plot(figsize=(12,8),title='Pandas Title')

# %% [markdown]
# ## Plot Formatting

# %% [markdown]
# **X Limits**

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'])

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2009-01-01'],ylim=[25,55])

# %% [markdown]
# **Color and Style**

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2007-05-01'],ylim=[0,40],ls='--',c='r')

# %% [markdown]
# **X Ticks**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
import matplotlib.dates as dates

# %%
mcdon['Adj. Close'].plot(xlim=['2007-01-01','2007-05-01'],ylim=[0,40])

# %%
idx = mcdon.loc['2007-01-01':'2007-05-01'].index
stock = mcdon.loc['2007-01-01':'2007-05-01']['Adj. Close']

# %% [markdown]
# **Basic matplotlib plot**

# %%
fig, ax = plt.subplots()
ax.plot_date(idx, stock,'-')
plt.tight_layout()
plt.show()

# %% [markdown]
# **Fix the overlap!**

# %%
fig, ax = plt.subplots()
ax.plot_date(idx, stock,'-')

fig.autofmt_xdate() # Auto fixes the overlap!
plt.tight_layout()
plt.show()

# %% [markdown]
# **Customize grid**

# %%
fig, ax = plt.subplots()
ax.plot_date(idx, stock,'-')
ax.yaxis.grid(True)
ax.xaxis.grid(True)
fig.autofmt_xdate() # Auto fixes the overlap!
plt.tight_layout()
plt.show()

# %% [markdown]
# **Format dates on Major Axis**

# %%
fig, ax = plt.subplots()
ax.plot_date(idx, stock,'-')

# Grids
ax.yaxis.grid(True)
ax.xaxis.grid(True)

# Major Axis
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('%b\n%Y'))

fig.autofmt_xdate() # Auto fixes the overlap!
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot_date(idx, stock,'-')

# Grids
ax.yaxis.grid(True)
ax.xaxis.grid(True)

# Major Axis
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n\n\n%Y--%B'))

fig.autofmt_xdate() # Auto fixes the overlap!
plt.tight_layout()
plt.show()

# %% [markdown]
# **Minor Axis**

# %%
fig, ax = plt.subplots()
ax.plot_date(idx, stock,'-')


# Major Axis
ax.xaxis.set_major_locator(dates.MonthLocator())
ax.xaxis.set_major_formatter(dates.DateFormatter('\n\n%Y--%B'))

# Minor Axis
ax.xaxis.set_minor_locator(dates.WeekdayLocator())
ax.xaxis.set_minor_formatter(dates.DateFormatter('%d'))

# Grids
ax.yaxis.grid(True)
ax.xaxis.grid(True)

fig.autofmt_xdate() # Auto fixes the overlap!
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,8))
ax.plot_date(idx, stock,'-')


# Major Axis
ax.xaxis.set_major_locator(dates.WeekdayLocator(byweekday=1))
ax.xaxis.set_major_formatter(dates.DateFormatter('%B-%d-%a'))
# Grids
ax.yaxis.grid(True)
ax.xaxis.grid(True)

fig.autofmt_xdate() # Auto fixes the overlap!

plt.tight_layout()
plt.show()
